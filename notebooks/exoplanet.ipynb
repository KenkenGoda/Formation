# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/Users/shohei/Desktop/Shohei/Fresnel/exoplanet.eu_catalog.csv')

# %%
data
# Out:
#                       # name planet_status      mass  mass_error_min  \
# 0      OGLE-2016-BLG-1469L b     Confirmed  13.60000         3.00000
# 1                   11 Com b     Confirmed  19.40000         1.50000
# 2                   11 Oph b     Confirmed  21.00000         3.00000
# 3                   11 UMi b     Confirmed  10.50000         2.47000
# 4                   14 And b     Confirmed   5.33000         0.57000
# 5                   14 Her b     Confirmed   4.64000         0.19000
# 6                 16 Cyg B b     Confirmed   1.68000         0.07000
# 7                   18 Del b     Confirmed  10.30000             NaN
# 8                1RXS 1609 b     Confirmed  14.00000         3.00000
# 9             1SWASP J1407 b     Confirmed  20.00000         6.00000
# 10                  24 Sex b     Confirmed   1.99000         0.38000
# 11                  24 Sex c     Confirmed   0.86000         0.22000
# 12         2M 0103-55 (AB) b     Confirmed  13.00000         1.00000
# ...

# %%
data.isnull().sum()
# Out:
# # name                           0
# planet_status                    0
# mass                          2150
# mass_error_min                2340
# mass_error_max                2354
# mass_sini                     2872
# mass_sini_error_min           3034
# mass_sini_error_max           3035
# radius                         907
# radius_error_min               981
# radius_error_max               981
# orbital_period                 136
# orbital_period_error_min       260
# orbital_period_error_max       259
# semi_major_axis               1476
# semi_major_axis_error_min     2472
# semi_major_axis_error_max     2472
# eccentricity                  2430
# eccentricity_error_min        2678
# eccentricity_error_max        2692
# inclination                   3065
# inclination_error_min         3102
# inclination_error_max         3098
# angular_distance              3078
# discovered                       1
# updated                          0
# omega                         2951
# ...

# %%
data.groupby(by='planet_status').sum()
# Out:
#                       mass  mass_error_min  mass_error_max    mass_sini  \
# planet_status
# Confirmed      6803.762379             inf             inf  2781.950226
#
#                mass_sini_error_min  mass_sini_error_max      radius  \
# planet_status
# Confirmed                      inf                  inf  1081.40098
#
#                radius_error_min  radius_error_max  orbital_period  \
# planet_status
# Confirmed            120.219964        154.766979    2.660660e+06
#
#                       ...           star_mass_error_max  star_radius  \
# planet_status         ...
# Confirmed             ...                           inf    5045.5759
#
#                star_radius_error_min  star_radius_error_max    star_age  \
# planet_status
# Confirmed                   577.3479               776.8858  4532.75165
#
#                star_age_error_min  star_age_error_max   star_teff  \
# planet_status
# Confirmed                     inf                 inf  19277749.5
#
# ...
